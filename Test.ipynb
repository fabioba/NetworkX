# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
G= nx.path_graph(8)

# %%
nx.draw(G)
plt.show()

# %%
G=nx.Graph()

# %%
G.add_node(1)
G.add_node(2)
G.add_node(3)

# %%
G.add_edge(1,2)

# %%
nx.draw(G,with_labels=True)
plt.show()

# %%
G.add_edge(1,3)
G.add_edge(2,3)

# %%
nx.draw(G,with_labels=True)
plt.show()
